# %% [markdown]
# <a href="https://colab.research.google.com/github/aetev/Learning-stuff-/blob/main/YF%20RL%20soft%20update%20test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tf_agents[reverb]
# Out:
# Collecting tf_agents[reverb]
#   Downloading tf_agents-0.18.0-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from tf_agents[reverb]) (1.4.0)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tf_agents[reverb]) (2.2.1)
# Requirement already satisfied: gin-config>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tf_agents[reverb]) (0.5.0)
# Collecting gym<=0.23.0,>=0.17.0 (from tf_agents[reverb])
#   Downloading gym-0.23.0.tar.gz (624 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 kB 47.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from tf_agents[reverb]) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from tf_agents[reverb]) (9.4.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from tf_agents[reverb]) (1.16.0)
# Requirement already satisfied: protobuf>=3.11.3 in /usr/local/lib/python3.10/dist-packages (from tf_agents[reverb]) (3.20.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from tf_agents[reverb]) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from tf_agents[reverb]) (4.5.0)
# Collecting pygame==2.1.3 (from tf_agents[reverb])
#   Downloading pygame-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 57.4 MB/s eta 0:00:00
# Collecting tensorflow-probability~=0.22.0 (from tf_agents[reverb])
#   Downloading tensorflow_probability-0.22.0-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 56.7 MB/s eta 0:00:00
# Collecting rlds (from tf_agents[reverb])
#   Downloading rlds-0.1.8-py3-none-manylinux2010_x86_64.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 6.9 MB/s eta 0:00:00
# Collecting dm-reverb~=0.13.0 (from tf_agents[reverb])
#   Downloading dm_reverb-0.13.0-cp310-cp310-manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 46.0 MB/s eta 0:00:00
# Collecting tensorflow~=2.14.0 (from tf_agents[reverb])
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from dm-reverb~=0.13.0->tf_agents[reverb]) (0.1.8)
# Requirement already satisfied: portpicker in /usr/local/lib/python3.10/dist-packages (from dm-reverb~=0.13.0->tf_agents[reverb]) (1.5.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym<=0.23.0,>=0.17.0->tf_agents[reverb]) (0.0.8)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (16.0.6)
# Collecting ml-dtypes==0.2.0 (from tensorflow~=2.14.0->tf_agents[reverb])
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 72.8 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (2.3.0)
# Collecting wrapt>=1.11.1 (from tf_agents[reverb])
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf_agents[reverb]) (1.59.0)
# Collecting tensorboard<2.15,>=2.14 (from tensorflow~=2.14.0->tf_agents[reverb])
#   Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 94.5 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow~=2.14.0->tf_agents[reverb])
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 43.7 MB/s eta 0:00:00
# Collecting keras<2.15,>=2.14.0 (from tensorflow~=2.14.0->tf_agents[reverb])
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 80.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.22.0->tf_agents[reverb]) (4.4.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.14.0->tf_agents[reverb]) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (3.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from portpicker->dm-reverb~=0.13.0->tf_agents[reverb]) (5.9.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf_agents[reverb]) (3.2.2)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.23.0-py3-none-any.whl size=697631 sha256=86ca4f956b3f899d690827bef5cb6a8726a02f86a3378df435c7d8562e52ef7f
#   Stored in directory: /root/.cache/pip/wheels/3d/6f/b4/3991d4fae11d0ecb0754c11cc1b4e7745012850da4efaaf0b1
# Successfully built gym
# Installing collected packages: wrapt, tensorflow-probability, tensorflow-estimator, rlds, pygame, ml-dtypes, keras, gym, tf_agents, dm-reverb, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.15.0
#     Uninstalling wrapt-1.15.0:
#       Successfully uninstalled wrapt-1.15.0
#   Attempting uninstall: tensorflow-probability
#     Found existing installation: tensorflow-probability 0.20.1
#     Uninstalling tensorflow-probability-0.20.1:
#       Successfully uninstalled tensorflow-probability-0.20.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.3.1
#     Uninstalling ml-dtypes-0.3.1:
#       Successfully uninstalled ml-dtypes-0.3.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
# Successfully installed dm-reverb-0.13.0 gym-0.23.0 keras-2.14.0 ml-dtypes-0.2.0 pygame-2.1.3 rlds-0.1.8 tensorboard-2.14.1 tensorflow-2.14.0 tensorflow-estimator-2.14.0 tensorflow-probability-0.22.0 tf_agents-0.18.0 wrapt-1.14.1

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.31)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2023.7.22)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.lib.stride_tricks import sliding_window_view
import tracemalloc

import tensorflow_probability as tfp

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Concatenate, GaussianNoise
from tensorflow.keras.regularizers import l2

from tf_agents.networks import network
from tf_agents.agents.categorical_dqn import categorical_dqn_agent
from tf_agents.environments import py_environment, tf_py_environment, utils
from tf_agents.specs import array_spec, tensor_spec
from tf_agents.trajectories import trajectory, time_step as ts
from tf_agents.replay_buffers.tf_uniform_replay_buffer import TFUniformReplayBuffer
from tf_agents.policies.random_tf_policy import RandomTFPolicy
from tf_agents.policies.boltzmann_policy import BoltzmannPolicy
from tf_agents.policies import tf_policy
from tf_agents.utils import common

# %%
BATCH_SIZE = 64 # @param {type:"integer"}
EVAL_EPISODES = 3 # @param {type:"integer"}
NUMBER_EPISODES = 10000000000 # @param {type:"integer"}
COLLECTION_STEPS = 1 # @param {type:"integer"}
EVAL_INTERVAL =  500 # @param {type:"integer"}

# %% [markdown]
# ### <font color='purple'><center>**-------------------Create Data-------------------**</font>

# %%
end_date = datetime.now()
start_date = end_date - timedelta(days=729)

tickers = [
    'EURUSD=X', 'USDEUR=X',  # Euro/US Dollar
    'USDJPY=X', 'JPYUSD=X',  # US Dollar/Japanese Yen
    'GBPUSD=X', 'USDGBP=X',  # British Pound/US Dollar
    'USDCHF=X', 'CHFUSD=X',  # US Dollar/Swiss Franc
    'AUDUSD=X', 'USDAUD=X',  # Australian Dollar/US Dollar
    'USDCAD=X', 'CADUSD=X',  # US Dollar/Canadian Dollar
    'NZDUSD=X', 'USDNZD=X',  # New Zealand Dollar/US Dollar
]

data_list = []
for ticker in tickers:
    data = yf.download(ticker, start=start_date, end=end_date, interval='1h')
    data_list.append(data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
def create_data(raw_data, window_size):
    High = raw_data['High'].to_numpy()
    Close = raw_data['Close'].to_numpy()
    Low = raw_data['Low'].to_numpy()
    Std = np.std(np.diff(Close))
    Close_Diff = np.diff(Close)/Std
    High_Adj = (High[1:]-Close[1:])/Std
    Low_Adj = (Close[1:]-Low[1:])/Std

    stack = np.stack((Close_Diff, High_Adj, Low_Adj), axis=1)

    window_view = np.lib.stride_tricks.sliding_window_view(stack, (window_size,),axis=0)

    Forex_Data = window_view[:-1]
    Forex_Data = Forex_Data.astype('float32')
    target = Close_Diff[window_size:]

    return Forex_Data, target

# %%
window_list = []
target_list = []
for data in data_list:
    window, target =  create_data(data, 50)
    window_list.append(window)
    target_list.append(target)

# %% [markdown]
# ### <font color='red'><center>**-------------------Create Environment-------------------**</font>

# %%
def custom_formatter(x):
  return f'{x:.4f}'

def test_environment(env, num_steps):
    # Reset the environment
    observation = env.reset()

    # Get the upper bound of the action range
    action_spec = env.action_spec().maximum

    # Loop through the time steps and take random actions
    for _ in range(num_steps):
        # Select a random action from the range of valid values
        action = np.random.randint(0, action_spec)

        # Execute the action and get the next observation, reward, done, and info
        observation, reward, done, info = env.step(action)

        # Print the current time step
        np.set_printoptions(formatter={'float_kind':custom_formatter})
        print(action,"{:.4f}".format(reward),info[1])

# %%
def SortinoRatio(df, T):
    """Calculates the Sortino ratio from univariate excess returns.

    Args:
        df ([float]): The dataframe or pandas series of univariate excess returns.
        T ([integer]): The targeted return.
    """

    # Check if there are less than two numbers in the array or no downside returns
    if len(df) < 2:
        return -1
    if np.all(df >= T):
        return 0

    #downside deviation:
    temp = np.minimum(0, df - T)**2
    temp_expectation = np.mean(temp)
    downside_dev = np.sqrt(temp_expectation)

    #Sortino ratio:
    sortino_ratio = np.mean(df - T) / downside_dev

    return(sortino_ratio)

# %%
start = 1
epi_length = 100
class TradingEnv(py_environment.PyEnvironment):

  def __init__(self):
    global start
    self._action_spec = array_spec.BoundedArraySpec(
        shape=(), dtype=np.int64, minimum=0, maximum=3, name='action')

    self._observation_spec = (
        array_spec.BoundedArraySpec(shape=(3,50), dtype=np.float32, name='observation1'),
        array_spec.BoundedArraySpec(shape=(2,), dtype=np.float32, name='observation2')
    )

    self._count = np.random.randint(1,10000)#startstart
    self._ticker = np.random.randint(0,len(window_list))

    self._max_ep_len = self._count + epi_length
    self._scaler = np.sum(np.absolute(target_list[self._ticker][self._count:self._max_ep_len]))
    self._state = (window_list[self._ticker][self._count-1], np.array([0, 0], dtype=np.float32))
    self._episode_ended = False

    self._trade_info = {'value': 0,'direction': 0}
    self._balance = np.array([])
    self._new = False


  def action_spec(self):
    return self._action_spec

  def observation_spec(self):
    return self._observation_spec

  def get_balance(self):
    return self._balance

  def _reset(self):
    global start
    self._count = np.random.randint(1,10000)#start
    self._ticker = np.random.randint(0,len(window_list))
    self._max_ep_len = self._count + epi_length
    self._scaler = np.sum(np.absolute(target_list[self._ticker][self._count:self._max_ep_len]))
    self._state = (window_list[self._ticker][self._count-1], np.array([0, 0], dtype=np.float32))
    self._episode_ended = False
    self._trade_info = {'value': 0,'direction': 0}
    self._balance = np.array([])
    self._new = False


    return ts.restart(self._state)

  def _step(self, action):
    global start

    if self._episode_ended:
      return self.reset()

    profit = 0
    reward = 0
    fee = 0
    cur_target = target_list[self._ticker][self._count]


    if action == 0:
        profit = self._trade_info['value']
        self._trade_info['value'] = cur_target
        self._trade_info['direction'] = 1
    elif action == 1:
        profit = self._trade_info['value']
        self._trade_info['value'] = -cur_target
        self._trade_info['direction'] = -1
    elif action == 2:
        self._trade_info['value'] += cur_target*self._trade_info['direction']
    else:
        profit = self._trade_info['value']
        self._trade_info['value'] = 0
        self._trade_info['direction'] = 0


    reward = profit



    trade_array = np.array([self._trade_info['value'],self._trade_info['direction']], dtype=np.float32)


    self._state = (window_list[self._ticker][self._count], trade_array)

    if profit != 0:
        self._balance = np.append(profit,self._balance)



    if self._count >= self._max_ep_len:
        if self._trade_info['value'] < 0:
            self._balance = np.append(profit,self._balance)
        self._episode_ended = True

    self._count += 1

    if self._episode_ended:
      #reward = SortinoRatio(self._balance,0)
      reward = np.mean(self._balance) if np.sum(self._balance) != 0 else 0
      return ts.termination(self._state, reward=reward)
    else:
      return ts.transition(self._state, reward=reward/50, discount=.99)



env = TradingEnv()
utils.validate_py_environment(env, episodes=2)

print('Observation Spec:')
print(env.time_step_spec().observation)

print('Reward Spec:')
print(env.time_step_spec().reward)

print('Action Spec:')
print(env.action_spec())

train_env = tf_py_environment.TFPyEnvironment(env)
evaluation_env = tf_py_environment.TFPyEnvironment(env)
# Out:
# Observation Spec:
# (BoundedArraySpec(shape=(3, 50), dtype=dtype('float32'), name='observation1', minimum=-3.4028234663852886e+38, maximum=3.4028234663852886e+38), BoundedArraySpec(shape=(2,), dtype=dtype('float32'), name='observation2', minimum=-3.4028234663852886e+38, maximum=3.4028234663852886e+38))
# Reward Spec:
# ArraySpec(shape=(), dtype=dtype('float32'), name='reward')
# Action Spec:
# BoundedArraySpec(shape=(), dtype=dtype('int64'), name='action', minimum=0, maximum=3)

# %%
test_environment(env,100)
# Out:
# 2 0.0000 [0.0000 0.0000]
# 1 0.0000 [-0.1830 -1.0000]
# 0 -0.0037 [-0.4449 1.0000]
# 1 -0.0089 [-0.9647 -1.0000]
# 0 -0.0193 [0.4908 1.0000]
# 2 0.0000 [0.4363 1.0000]
# 2 0.0000 [0.5901 1.0000]
# 1 0.0118 [-0.0893 -1.0000]
# 2 0.0000 [-0.0347 -1.0000]
# 1 -0.0007 [0.0943 -1.0000]
# 1 0.0019 [-0.2929 -1.0000]
# 1 -0.0059 [0.4367 -1.0000]
# 2 0.0000 [-0.0398 -1.0000]
# 2 0.0000 [0.7193 -1.0000]
# 1 0.0144 [-0.1834 -1.0000]
# 2 0.0000 [-0.2132 -1.0000]
# 1 -0.0043 [-0.8292 -1.0000]
# 0 -0.0166 [0.2884 1.0000]
# 2 0.0000 [0.0248 1.0000]
# 2 0.0000 [-1.0324 1.0000]
# 0 -0.0206 [-2.6165 1.0000]
# 0 -0.0523 [0.0836 1.0000]
# 2 0.0000 [-0.4227 1.0000]
# 1 -0.0085 [0.6330 -1.0000]
# 1 0.0127 [-1.3312 -1.0000]
# 2 0.0000 [-2.5244 -1.0000]
# 2 0.0000 [-1.9618 -1.0000]
# 2 0.0000 [-2.3171 -1.0000]
# 2 0.0000 [-1.0066 -1.0000]
# 0 -0.0201 [-0.6877 1.0000]
# 1 -0.0138 [0.0197 -1.0000]
# 0 0.0004 [-0.1520 1.0000]
# 1 -0.0030 [-0.5006 -1.0000]
# 2 0.0000 [-0.2845 -1.0000]
# 0 -0.0057 [-0.3973 1.0000]
# 2 0.0000 [-0.1619 1.0000]
# 0 -0.0032 [0.1669 1.0000]
# 1 0.0033 [-0.6634 -1.0000]
# 1 -0.0133 [-0.8618 -1.0000]
# 2 0.0000 [-1.0345 -1.0000]
# 0 -0.0207 [-0.7294 1.0000]
# 0 -0.0146 [0.1822 1.0000]
# 1 0.0036 [0.3200 -1.0000]
# 2 0.0000 [-0.6064 -1.0000]
# 2 0.0000 [-0.7693 -1.0000]
# 1 -0.0154 [0.0198 -1.0000]
# 1 0.0004 [-0.1728 -1.0000]
# 1 -0.0035 [-1.1082 -1.0000]
# 1 -0.0222 [1.6807 -1.0000]
# 2 0.0000 [2.2127 -1.0000]
# 2 0.0000 [3.3775 -1.0000]
# 2 0.0000 [3.7355 -1.0000]
# 0 0.0747 [-0.1568 1.0000]
# 0 -0.0031 [-0.3330 1.0000]
# 2 0.0000 [-0.5678 1.0000]
# 2 0.0000 [-0.4015 1.0000]
# 2 0.0000 [-0.2546 1.0000]
# 1 -0.0051 [-0.2742 -1.0000]
# 1 -0.0055 [0.0245 -1.0000]
# 0 0.0005 [0.3626 1.0000]
# 2 0.0000 [-0.2743 1.0000]
# 0 -0.0055 [0.0686 1.0000]
# 0 0.0014 [-0.4844 1.0000]
# 0 -0.0097 [-0.6252 1.0000]
# 2 0.0000 [-0.1027 1.0000]
# 0 -0.0021 [0.5674 1.0000]
# 0 0.0113 [-0.9386 1.0000]
# 2 0.0000 [-0.1566 1.0000]
# 1 -0.0031 [0.0734 -1.0000]
# 0 0.0015 [-0.6647 1.0000]
# 0 -0.0133 [-0.1513 1.0000]
# 1 -0.0030 [-0.2148 -1.0000]
# 1 -0.0043 [-0.9879 -1.0000]
# 2 0.0000 [-0.0831 -1.0000]
# 0 -0.0017 [0.1661 1.0000]
# 0 0.0033 [-0.3126 1.0000]
# 2 0.0000 [-0.0733 1.0000]
# 2 0.0000 [0.2347 1.0000]
# 1 0.0047 [-0.6363 -1.0000]
# 0 -0.0127 [-0.2351 1.0000]
# 2 0.0000 [-0.2987 1.0000]
# 1 -0.0060 [0.3278 -1.0000]
# 2 0.0000 [0.4500 -1.0000]
# 1 0.0090 [0.0391 -1.0000]
# 0 0.0008 [-0.1565 1.0000]
# 2 0.0000 [-1.4195 1.0000]
# 2 0.0000 [-1.2491 1.0000]
# 0 -0.0250 [0.5264 1.0000]
# 2 0.0000 [1.2735 1.0000]
# 1 0.0255 [0.5080 -1.0000]
# 1 0.0102 [-0.3174 -1.0000]
# 0 -0.0063 [-0.2052 1.0000]
# 0 -0.0041 [-0.5416 1.0000]
# 2 0.0000 [-0.4587 1.0000]
# 0 -0.0092 [-0.9106 1.0000]
# 0 -0.0182 [-0.7335 1.0000]
# 0 -0.0147 [0.1116 1.0000]
# 2 0.0000 [-0.4122 1.0000]
# 1 -0.0082 [-0.5821 -1.0000]
# 2 0.0000 [0.0969 -1.0000]

# %% [markdown]
# ### <font color='blue'><center>**-------------------Create Network-------------------**</font>

# %%
class CustomQNetwork(network.Network):
    def __init__(self, input_tensor_spec, action_spec, name='CustomQNetwork'):
        super(CustomQNetwork, self).__init__(input_tensor_spec=input_tensor_spec,
                                             state_spec=(),
                                             name=name)
        # Define your custom layers and architecture here
        self.LSTM1 = LSTM(units=200, activation='gelu', return_sequences=True)
        self.LSTM2 = LSTM(units=200, activation='gelu', return_sequences=False)
        self.BatchNorm1 = BatchNormalization()
        self.Concat = Concatenate()
        self.Dense1 = Dense(200,activation='gelu')
        self.BatchNorm2 = BatchNormalization()
        self.Dense2 = Dense(200,activation='gelu')
        self.BatchNorm3 = BatchNormalization()
        self.q_values_layer = Dense(action_spec.maximum - action_spec.minimum + 1,
                                                    activation=None)
        self.gaussian_noise_layer = GaussianNoise(stddev=.4)  # Add Gaussian noise with stddev=0.2

    def call(self, observation, step_type=None, network_state=(), training=False):
        # Split the observation into two arrays
        observation1, observation2 = observation

        if training:
            observation1 = self.gaussian_noise_layer(observation1)

        x = self.LSTM1(observation1)
        x = self.LSTM2(x)
        x = self.BatchNorm1(x)
        x = self.Concat([x,observation2])
        x = self.Dense1(x)
        x = self.BatchNorm2(x)
        x = self.Dense2(x)
        x = self.BatchNorm3(x)
        q_values = self.q_values_layer(x)
        return q_values, network_state

# %%
class CategoricalQNetwork(network.Network):
    def __init__(self, input_tensor_spec, action_spec, num_atoms=51, preprocessing_layers=None,
                 preprocessing_combiner=None, conv_layer_params=None, fc_layer_params=None,
                 activation_fn=tf.nn.relu, name='CategoricalQNetwork'):
        super(CategoricalQNetwork, self).__init__(input_tensor_spec=input_tensor_spec,
                                                  state_spec=(),
                                                  name=name)
        # Check if action_spec is a BoundedTensorSpec
        if not isinstance(action_spec, tensor_spec.BoundedTensorSpec):
            raise TypeError('action_spec must be a BoundedTensorSpec. Got: %s' % (action_spec,))

        self._num_actions = action_spec.maximum - action_spec.minimum + 1
        self._num_atoms = num_atoms

        # Create a BoundedTensorSpec for the q_network action
        q_network_action_spec = tensor_spec.BoundedTensorSpec((), tf.int32,
                                                              minimum=0,
                                                              maximum=self._num_actions * num_atoms - 1)

        # Create the q_network
        self._q_network = CustomQNetwork(input_tensor_spec=input_tensor_spec,
                                             action_spec=q_network_action_spec,
                                             )
    def call(self, observation, step_type=None, network_state=(), training=False):
        logits, network_state = self._q_network(observation, step_type, network_state, training=training)
        logits = tf.reshape(logits, [-1, self._num_actions, self._num_atoms])
        return logits, network_state
    @property
    def num_atoms(self):
        return self._num_atoms

# %%
observation_spec = train_env.observation_spec()
action_spec = train_env.action_spec()
num_atoms = 51
custom_network = CategoricalQNetwork(observation_spec,action_spec, num_atoms)

# %%
EPSILON_INIT = .5
EPSILON_MIN = 0.1
EPSILON_DECAY_STEPS = 2e5


# Define the epsilon decay function
def epsilon_decay(global_step):
    epsilon = EPSILON_INIT - (EPSILON_INIT - EPSILON_MIN) * tf.minimum(1.0, tf.cast(global_step, tf.float32) / EPSILON_DECAY_STEPS)
    return epsilon
train_env

# %%
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=0.001)
global_step = tf.Variable(0, name='global_step', trainable=False)
train_step_counter = tf.Variable(0)

C51_agent = categorical_dqn_agent.CategoricalDqnAgent(
    train_env.time_step_spec(),
    train_env.action_spec(),
    categorical_q_network=custom_network,
    optimizer=optimizer,
    min_q_value=-20,
    max_q_value=20,
    epsilon_greedy=None,
    n_step_update=2,
    boltzmann_temperature=.5,
    target_update_period=100,
    td_errors_loss_fn=common.element_wise_squared_loss,
    gamma=1,
    train_step_counter=train_step_counter)
C51_agent.initialize()

# %% [markdown]
# ### <font color='green'><center>**-------------------Create Replay Buffer And Training Loop-------------------**</font>

# %%
def timestamp_data(environment, policy, replay_buffer):
        time_step = environment.current_time_step()
        action_step = policy.action(time_step)
        next_time_step = environment.step(action_step.action)
        timestamp_trajectory = trajectory.from_transition(time_step, action_step, next_time_step)
        replay_buffer.add_batch(timestamp_trajectory)

# %%
replay_buffer.clear()
#define replay buffer
replay_buffer = TFUniformReplayBuffer(
            data_spec=C51_agent.collect_data_spec,
            batch_size=train_env.batch_size,
            max_length=50000)

#random policy for filling buffer
random_policy = RandomTFPolicy(train_env.time_step_spec(),
                                                train_env.action_spec())

train_env.reset()
#fill replay buffer
for _ in range(1000):
    timestamp_data(train_env, random_policy,replay_buffer)

#create dataset from buffer
dataset = replay_buffer.as_dataset(
            num_parallel_calls=tf.data.AUTOTUNE,
            sample_batch_size=BATCH_SIZE,
            num_steps=2).prefetch(tf.data.AUTOTUNE)

iterator = iter(dataset)

# %%
#define checkpointer
checkpoint_dir = '/tmp/MODEL2'

train_checkpointer = common.Checkpointer(
        ckpt_dir=checkpoint_dir,
        max_to_keep=1,
        agent=C51_agent,
        policy=C51_agent.policy,
        replay_buffer=replay_buffer,
        global_step=global_step
    )

# %%
#train_checkpointer.initialize_or_restore(checkpoint_dir)

# %%
from scipy.stats import entropy
import scipy
# Get the distribution
time_step = train_env.current_time_step()
action_step = C51_agent.policy.action(time_step)
next_time_step = train_env.step(action_step.action)
state = time_step.observation
distributions = custom_network(state)[0][0]
testttt = tf.cast(distributions,tf.float32)
#softmax_distribution = tf.nn.softmax(testttt)
#entropy = -tf.reduce_sum(softmax_distribution * tf.math.log(softmax_distribution))

#the_val = testttt.numpy()
#val = scipy.stats.entropy(the_val)





def entropy_single(logits):
    #epsilon = 1e-10
    #min_value = tf.reduce_min(distribution)
    #tensor_subtracted = tf.subtract(distribution, min_value)
    #offset = tf.add(tensor_subtracted,epsilon)
    #sum_tensor = tf.reduce_sum(offset)
    #p = tf.divide(offset, sum_tensor)
    p = tf.nn.softmax(logits)
    return -tf.reduce_sum(p * tf.math.log(p))


def Entropy(Distribution):
    entropy_values = tf.map_fn(entropy_single, Distribution)
    highest_index = tf.math.argmax(entropy_values)
    return highest_index

for i in range(4):
    print(i)
    print(entropy_single(testttt[i]).numpy())
    dist = tf.nn.softmax(testttt[i])
    plt.bar(range(len(dist)), dist)
    #chart goes from low q to high q value
    plt.show()
print(Entropy(distributions).numpy())
#print(val)
# Out:
# 0
# 3.372165
# 1
# 3.351603
# 2
# 3.3689222
# 3
# 3.3593514
# 0

# %%
from tf_agents.trajectories import policy_step
class CustomPolicy(tf_policy.TFPolicy):
    def __init__(self, time_step_spec, action_spec,network,agent, name=None):
        super(CustomPolicy, self).__init__(
            time_step_spec,
            action_spec,
            policy_state_spec=(),
            clip=False,
            name=name)
        self._network = network
        self._agent = agent
        self._epsilon = epsilon_decay(global_step)

    def _action(self, time_step, policy_state=(), seed=None):
        # Define your action logic here


        if tf.random.uniform([], minval=0, maxval=1, dtype=tf.float32) < self._epsilon:
            Distribution = self._network(time_step.observation)[0][0]
            tensors = []

            highest_index = Entropy(Distribution)
            action = tf.cast(highest_index,tf.int64)
            action = tf.reshape(action,(1,))
        else:
            action = self._agent.policy.action(time_step)[0]
        return policy_step.PolicyStep(action, state=policy_state, info=())

    def _get_initial_state(self, batch_size=None):
        # Define your initial state logic here
        return ()

# %%
time_step_spec = train_env.time_step_spec()
action_spec = train_env.action_spec()
print(action_spec)
# Out:
# BoundedTensorSpec(shape=(), dtype=tf.int64, name='action', minimum=array(0), maximum=array(3))

# %%
my_policy = CustomPolicy(time_step_spec,action_spec,custom_network,C51_agent)

# %%
time_step = train_env.current_time_step()
action_step = my_policy.action(time_step)

print(action_step)
# Out:
# PolicyStep(action=<tf.Tensor: shape=(1,), dtype=int64, numpy=array([3])>, state=(), info=())

# %%
def run_environment(env,policy):
    time_step = env.reset()

    while not time_step.is_last():
        action = policy.action(time_step)
        next_time_step = env.step(action)
        reward = next_time_step.reward
        time_step = next_time_step

    return reward

# %%
@tf.function
def train(agent):


    for step in tf.range(1000):
        for _ in tf.range(COLLECTION_STEPS):
        #while not time_step.is_last():
            timestamp_data(train_env, agent.collect_policy, replay_buffer)

        experience, info = next(iterator)
        train_loss = agent.train(experience).loss

        if step % EVAL_INTERVAL == 0:
            avg_reward = run_environment(evaluation_env,agent.policy)

            tf.print('Reward:',avg_reward[0],' Loss:',train_loss,' Epsilon:',epsilon_decay(global_step))


        #Increment the global step variable
        global_step.assign_add(1)


print("**********************************")
print("Training C51_agent")
print("**********************************")
for i in range(1000000000):
    C51_reward = train(C51_agent)
    #train_checkpointer.save(global_step)
# Out:
# **********************************
# Training C51_agent
# **********************************
# Reward: 0.176023766  Loss: 3.43069768  Epsilon: 0.49
# Reward: 0.0792709067  Loss: 3.41858029  Epsilon: 0.489

# %%
print(global_step)

# %%
def compute_avg_return_print(environment, policy, num_episodes=10):

  total_return = 0.0
  for episode in range(num_episodes):
    balance_arr = []
    time_step = environment.reset()
    episode_return = 0.0

    while not time_step.is_last():
      action_step = policy.action(time_step)
      time_step = environment.step(action_step.action)
      obs = time_step.observation

      balance = np.sum(env.get_balance())
      balance_arr.append(balance)
      # Print the episode number and observation at each step
      print(f"Episode {episode + 1}: Observation = {obs[1]}")

      episode_return += time_step.reward
    plt.plot(balance_arr)
    total_return += episode_return

  avg_return = total_return / num_episodes
  return avg_return.numpy()[0]

# %%
avg_return = compute_avg_return_print(evaluation_env, C51_agent.policy, 20)
print(avg_return)
# Out:
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.4953 1.0000]]
# Episode 1: Observation = [[1.0849 1.0000]]
# Episode 1: Observation = [[0.2123 -1.0000]]
# Episode 1: Observation = [[0.1336 -1.0000]]
# Episode 1: Observation = [[0.6132 -1.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[1.1558 1.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[1.7296 1.0000]]
# Episode 1: Observation = [[0.7940 -1.0000]]
# Episode 1: Observation = [[-0.3616 -1.0000]]
# Episode 1: Observation = [[-0.2437 -1.0000]]
# Episode 1: Observation = [[-0.1650 -1.0000]]
# Episode 1: Observation = [[-0.8726 -1.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[-0.5582 -1.0000]]
# Episode 1: Observation = [[0.0865 -1.0000]]
# Episode 1: Observation = [[0.0393 -1.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[-0.2123 1.0000]]
# Episode 1: Observation = [[0.2044 1.0000]]
# Episode 1: Observation = [[0.1179 1.0000]]
# Episode 1: Observation = [[-0.3538 1.0000]]
# Episode 1: Observation = [[0.7784 1.0000]]
# Episode 1: Observation = [[0.2515 1.0000]]
# Episode 1: Observation = [[-0.1022 1.0000]]
# Episode 1: Observation = [[0.0944 1.0000]]
# Episode 1: Observation = [[-0.8412 -1.0000]]
# Episode 1: Observation = [[-1.4701 -1.0000]]
# Episode 1: Observation = [[0.8176 1.0000]]
# Episode 1: Observation = [[0.6211 1.0000]]
# Episode 1: Observation = [[-0.1415 1.0000]]
# Episode 1: Observation = [[1.4781 1.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[-0.0944 1.0000]]
# Episode 1: Observation = [[0.1415 -1.0000]]
# Episode 1: Observation = [[0.0471 -1.0000]]
# Episode 1: Observation = [[0.0157 -1.0000]]
# Episode 1: Observation = [[-0.0550 -1.0000]]
# Episode 1: Observation = [[0.2908 -1.0000]]
# Episode 1: Observation = [[0.1730 -1.0000]]
# Episode 1: Observation = [[-1.0535 -1.0000]]
# Episode 1: Observation = [[0.1022 1.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.7390 1.0000]]
# Episode 1: Observation = [[0.4717 1.0000]]
# Episode 1: Observation = [[0.5503 1.0000]]
# Episode 1: Observation = [[0.4561 1.0000]]
# Episode 1: Observation = [[-0.4639 1.0000]]
# Episode 1: Observation = [[-1.6667 1.0000]]
# Episode 1: Observation = [[-0.6761 -1.0000]]
# Episode 1: Observation = [[-0.3223 -1.0000]]
# Episode 1: Observation = [[-0.1415 -1.0000]]
# Episode 1: Observation = [[0.1573 -1.0000]]
# Episode 1: Observation = [[-0.0000 -1.0000]]
# Episode 1: Observation = [[-0.2123 -1.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 1: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[-0.7026 1.0000]]
# Episode 2: Observation = [[-3.8868 1.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 2: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[3.0103 -1.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 3: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.2052 -1.0000]]
# Episode 4: Observation = [[1.3475 -1.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[-3.1350 -1.0000]]
# Episode 4: Observation = [[-3.9292 -1.0000]]
# Episode 4: Observation = [[-0.1914 -1.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 4: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.1736 -1.0000]]
# Episode 5: Observation = [[0.6510 -1.0000]]
# Episode 5: Observation = [[-0.0868 -1.0000]]
# Episode 5: Observation = [[0.6076 -1.0000]]
# Episode 5: Observation = [[-1.8054 -1.0000]]
# Episode 5: Observation = [[-1.4755 -1.0000]]
# Episode 5: Observation = [[-1.2412 -1.0000]]
# Episode 5: Observation = [[-2.5301 -1.0000]]
# Episode 5: Observation = [[-3.2375 -1.0000]]
# Episode 5: Observation = [[-2.4042 -1.0000]]
# Episode 5: Observation = [[-0.1042 -1.0000]]
# Episode 5: Observation = [[1.6752 -1.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[-1.3453 -1.0000]]
# Episode 5: Observation = [[1.3887 -1.0000]]
# Episode 5: Observation = [[-0.0434 -1.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[-1.1717 -1.0000]]
# Episode 5: Observation = [[-0.5642 1.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.4731 -1.0000]]
# Episode 5: Observation = [[-0.3515 -1.0000]]
# Episode 5: Observation = [[-0.3862 -1.0000]]
# Episode 5: Observation = [[-0.1736 1.0000]]
# Episode 5: Observation = [[0.0434 -1.0000]]
# Episode 5: Observation = [[0.5034 -1.0000]]
# Episode 5: Observation = [[0.1996 1.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[-0.6076 1.0000]]
# Episode 5: Observation = [[-1.5623 1.0000]]
# Episode 5: Observation = [[-1.3454 1.0000]]
# Episode 5: Observation = [[-0.0434 1.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[-0.7812 1.0000]]
# Episode 5: Observation = [[-1.1284 -1.0000]]
# Episode 5: Observation = [[-0.2170 -1.0000]]
# Episode 5: Observation = [[-0.0868 -1.0000]]
# Episode 5: Observation = [[0.0868 -1.0000]]
# Episode 5: Observation = [[-0.8072 -1.0000]]
# Episode 5: Observation = [[-1.7489 -1.0000]]
# Episode 5: Observation = [[2.6690 -1.0000]]
# Episode 5: Observation = [[0.9938 -1.0000]]
# Episode 5: Observation = [[1.4061 -1.0000]]
# Episode 5: Observation = [[-0.6944 1.0000]]
# Episode 5: Observation = [[-0.1302 1.0000]]
# Episode 5: Observation = [[-0.8679 1.0000]]
# Episode 5: Observation = [[-0.3038 1.0000]]
# Episode 5: Observation = [[-0.3472 1.0000]]
# Episode 5: Observation = [[-0.0434 -1.0000]]
# Episode 5: Observation = [[-0.2994 -1.0000]]
# Episode 5: Observation = [[-0.6250 -1.0000]]
# Episode 5: Observation = [[0.7074 -1.0000]]
# Episode 5: Observation = [[1.0936 -1.0000]]
# Episode 5: Observation = [[0.5858 -1.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[-0.1692 1.0000]]
# Episode 5: Observation = [[-1.1153 1.0000]]
# Episode 5: Observation = [[-0.6987 1.0000]]
# Episode 5: Observation = [[0.2430 -1.0000]]
# Episode 5: Observation = [[0.4817 -1.0000]]
# Episode 5: Observation = [[0.5555 -1.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[-0.8245 -1.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[-0.1172 -1.0000]]
# Episode 5: Observation = [[-0.2430 -1.0000]]
# Episode 5: Observation = [[-0.3081 -1.0000]]
# Episode 5: Observation = [[-0.8636 -1.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 5: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[-0.0926 -1.0000]]
# Episode 6: Observation = [[-0.0310 -1.0000]]
# Episode 6: Observation = [[0.0310 -1.0000]]
# Episode 6: Observation = [[-0.0463 -1.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[-1.0357 1.0000]]
# Episode 6: Observation = [[-0.7658 1.0000]]
# Episode 6: Observation = [[-0.0996 1.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[-0.5685 -1.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[-0.4540 -1.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[-0.0615 1.0000]]
# Episode 6: Observation = [[-0.6295 1.0000]]
# Episode 6: Observation = [[-1.1495 1.0000]]
# Episode 6: Observation = [[-0.9941 1.0000]]
# Episode 6: Observation = [[-0.3054 1.0000]]
# Episode 6: Observation = [[-0.2214 1.0000]]
# Episode 6: Observation = [[0.0534 1.0000]]
# Episode 6: Observation = [[0.3207 1.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[-0.5733 -1.0000]]
# Episode 6: Observation = [[0.1071 -1.0000]]
# Episode 6: Observation = [[0.0383 -1.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.3221 -1.0000]]
# Episode 6: Observation = [[0.2607 1.0000]]
# Episode 6: Observation = [[0.9512 1.0000]]
# Episode 6: Observation = [[0.3760 -1.0000]]
# Episode 6: Observation = [[0.5526 -1.0000]]
# Episode 6: Observation = [[0.6592 -1.0000]]
# Episode 6: Observation = [[0.0307 1.0000]]
# Episode 6: Observation = [[-0.7579 1.0000]]
# Episode 6: Observation = [[-0.4822 -1.0000]]
# Episode 6: Observation = [[0.7729 -1.0000]]
# Episode 6: Observation = [[-0.6963 -1.0000]]
# Episode 6: Observation = [[-0.1836 -1.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 6: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.2999 -1.0000]]
# Episode 7: Observation = [[1.0633 -1.0000]]
# Episode 7: Observation = [[-0.1090 -1.0000]]
# Episode 7: Observation = [[0.0164 -1.0000]]
# Episode 7: Observation = [[-0.3981 1.0000]]
# Episode 7: Observation = [[0.5507 1.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[-0.3436 1.0000]]
# Episode 7: Observation = [[-1.6632 1.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[-0.2891 -1.0000]]
# Episode 7: Observation = [[-0.0109 -1.0000]]
# Episode 7: Observation = [[-0.0927 -1.0000]]
# Episode 7: Observation = [[-0.4580 -1.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[-0.4253 -1.0000]]
# Episode 7: Observation = [[-0.7143 -1.0000]]
# Episode 7: Observation = [[-1.4723 -1.0000]]
# Episode 7: Observation = [[-2.8301 -1.0000]]
# Episode 7: Observation = [[0.2727 1.0000]]
# Episode 7: Observation = [[-0.2945 1.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[1.3687 -1.0000]]
# Episode 7: Observation = [[-1.1452 -1.0000]]
# Episode 7: Observation = [[-0.0491 -1.0000]]
# Episode 7: Observation = [[-0.2126 -1.0000]]
# Episode 7: Observation = [[-0.4035 -1.0000]]
# Episode 7: Observation = [[-0.4635 -1.0000]]
# Episode 7: Observation = [[0.1200 -1.0000]]
# Episode 7: Observation = [[0.1800 -1.0000]]
# Episode 7: Observation = [[-0.9052 -1.0000]]
# Episode 7: Observation = [[0.3708 1.0000]]
# Episode 7: Observation = [[-1.0142 1.0000]]
# Episode 7: Observation = [[-0.4526 -1.0000]]
# Episode 7: Observation = [[0.4526 -1.0000]]
# Episode 7: Observation = [[-1.7995 1.0000]]
# Episode 7: Observation = [[1.1451 1.0000]]
# Episode 7: Observation = [[-1.9085 1.0000]]
# Episode 7: Observation = [[0.3817 1.0000]]
# Episode 7: Observation = [[-1.7886 1.0000]]
# Episode 7: Observation = [[0.9107 1.0000]]
# Episode 7: Observation = [[-0.0327 1.0000]]
# Episode 7: Observation = [[-0.8997 1.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[3.2772 1.0000]]
# Episode 7: Observation = [[-1.2760 1.0000]]
# Episode 7: Observation = [[-0.8016 1.0000]]
# Episode 7: Observation = [[-0.9925 1.0000]]
# Episode 7: Observation = [[0.8725 1.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[-0.6216 1.0000]]
# Episode 7: Observation = [[-0.2181 1.0000]]
# Episode 7: Observation = [[0.2018 1.0000]]
# Episode 7: Observation = [[-0.2181 1.0000]]
# Episode 7: Observation = [[-2.3284 1.0000]]
# Episode 7: Observation = [[-1.4123 1.0000]]
# Episode 7: Observation = [[-1.9412 1.0000]]
# Episode 7: Observation = [[-1.8322 1.0000]]
# Episode 7: Observation = [[-1.2269 1.0000]]
# Episode 7: Observation = [[-3.8662 1.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 7: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[-0.7026 1.0000]]
# Episode 8: Observation = [[-3.8868 1.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[-1.2135 1.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.1277 1.0000]]
# Episode 8: Observation = [[-1.1770 1.0000]]
# Episode 8: Observation = [[-1.9525 1.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[1.0311 1.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.4562 1.0000]]
# Episode 8: Observation = [[0.3467 1.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[-0.0730 1.0000]]
# Episode 8: Observation = [[-0.3285 1.0000]]
# Episode 8: Observation = [[-1.6788 1.0000]]
# Episode 8: Observation = [[0.7117 1.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.4471 1.0000]]
# Episode 8: Observation = [[1.0311 1.0000]]
# Episode 8: Observation = [[0.1551 1.0000]]
# Episode 8: Observation = [[0.6022 1.0000]]
# Episode 8: Observation = [[1.0584 1.0000]]
# Episode 8: Observation = [[-1.0493 1.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 8: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[1.1519 1.0000]]
# Episode 9: Observation = [[0.9672 1.0000]]
# Episode 9: Observation = [[-0.3579 1.0000]]
# Episode 9: Observation = [[-0.3172 -1.0000]]
# Episode 9: Observation = [[0.7641 -1.0000]]
# Episode 9: Observation = [[-3.6107 1.0000]]
# Episode 9: Observation = [[-0.4596 1.0000]]
# Episode 9: Observation = [[-0.1129 1.0000]]
# Episode 9: Observation = [[-0.5241 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[-0.5309 -1.0000]]
# Episode 9: Observation = [[-1.0946 -1.0000]]
# Episode 9: Observation = [[-0.4188 1.0000]]
# Episode 9: Observation = [[-0.3543 1.0000]]
# Episode 9: Observation = [[-0.3140 -1.0000]]
# Episode 9: Observation = [[0.1450 -1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[-1.2413 -1.0000]]
# Episode 9: Observation = [[-1.7742 -1.0000]]
# Episode 9: Observation = [[-0.1939 -1.0000]]
# Episode 9: Observation = [[0.4684 -1.0000]]
# Episode 9: Observation = [[0.5083 -1.0000]]
# Episode 9: Observation = [[1.0401 -1.0000]]
# Episode 9: Observation = [[-1.3739 -1.0000]]
# Episode 9: Observation = [[-1.4143 -1.0000]]
# Episode 9: Observation = [[-0.1779 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0647 1.0000]]
# Episode 9: Observation = [[-0.1618 1.0000]]
# Episode 9: Observation = [[3.6355 1.0000]]
# Episode 9: Observation = [[1.7618 1.0000]]
# Episode 9: Observation = [[2.6532 1.0000]]
# Episode 9: Observation = [[-0.2537 1.0000]]
# Episode 9: Observation = [[-1.6425 1.0000]]
# Episode 9: Observation = [[-1.5772 1.0000]]
# Episode 9: Observation = [[-0.5971 1.0000]]
# Episode 9: Observation = [[-0.6789 1.0000]]
# Episode 9: Observation = [[-0.9077 1.0000]]
# Episode 9: Observation = [[-0.9241 1.0000]]
# Episode 9: Observation = [[-1.1690 1.0000]]
# Episode 9: Observation = [[-2.1155 1.0000]]
# Episode 9: Observation = [[-2.2295 1.0000]]
# Episode 9: Observation = [[-3.2067 1.0000]]
# Episode 9: Observation = [[-2.8812 1.0000]]
# Episode 9: Observation = [[0.5701 1.0000]]
# Episode 9: Observation = [[-0.0489 1.0000]]
# Episode 9: Observation = [[0.2687 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.9133 1.0000]]
# Episode 9: Observation = [[-1.0356 1.0000]]
# Episode 9: Observation = [[-2.7758 1.0000]]
# Episode 9: Observation = [[-2.3942 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[-0.9287 1.0000]]
# Episode 9: Observation = [[-0.3342 1.0000]]
# Episode 9: Observation = [[-0.4891 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[-0.2938 1.0000]]
# Episode 9: Observation = [[-0.3101 1.0000]]
# Episode 9: Observation = [[-0.7504 1.0000]]
# Episode 9: Observation = [[-0.7504 1.0000]]
# Episode 9: Observation = [[0.2776 1.0000]]
# Episode 9: Observation = [[0.8823 1.0000]]
# Episode 9: Observation = [[0.8006 1.0000]]
# Episode 9: Observation = [[1.1849 1.0000]]
# Episode 9: Observation = [[2.0282 1.0000]]
# Episode 9: Observation = [[-0.7778 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.1474 1.0000]]
# Episode 9: Observation = [[0.4832 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[-0.6892 1.0000]]
# Episode 9: Observation = [[-1.2055 1.0000]]
# Episode 9: Observation = [[-1.0392 1.0000]]
# Episode 9: Observation = [[0.0082 1.0000]]
# Episode 9: Observation = [[0.3108 1.0000]]
# Episode 9: Observation = [[0.4089 1.0000]]
# Episode 9: Observation = [[-0.2779 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[0.0409 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[1.4001 1.0000]]
# Episode 9: Observation = [[0.6235 1.0000]]
# Episode 9: Observation = [[0.0000 0.0000]]
# Episode 9: Observation = [[2.0278 1.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[-5.1972 1.0000]]
# Episode 10: Observation = [[-4.0117 1.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[-0.4656 -1.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.0000 0.0000]]
# Episode 10: Observation = [[0.4076 1.0000]]
# Episode 10: Observation = [[-0.3167 1.0000]]
# Episode 10: Observation = [[-2.3335 1.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[-0.3933 -1.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.2672 1.0000]]
# Episode 11: Observation = [[0.2895 1.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.2081 -1.0000]]
# Episode 11: Observation = [[-0.1264 -1.0000]]
# Episode 11: Observation = [[-0.1709 -1.0000]]
# Episode 11: Observation = [[-0.4166 -1.0000]]
# Episode 11: Observation = [[-1.3710 -1.0000]]
# Episode 11: Observation = [[-1.2964 -1.0000]]
# Episode 11: Observation = [[-0.6645 -1.0000]]
# Episode 11: Observation = [[-0.3806 -1.0000]]
# Episode 11: Observation = [[0.5220 -1.0000]]
# Episode 11: Observation = [[-0.8952 -1.0000]]
# Episode 11: Observation = [[-1.0893 -1.0000]]
# Episode 11: Observation = [[-0.7773 -1.0000]]
# Episode 11: Observation = [[-0.1643 -1.0000]]
# Episode 11: Observation = [[-0.9494 -1.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.9327 1.0000]]
# Episode 11: Observation = [[0.5263 1.0000]]
# Episode 11: Observation = [[1.0155 1.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.3527 -1.0000]]
# Episode 11: Observation = [[-0.0750 -1.0000]]
# Episode 11: Observation = [[0.5177 -1.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[-0.6666 -1.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[1.1735 1.0000]]
# Episode 11: Observation = [[1.0232 -1.0000]]
# Episode 11: Observation = [[2.6590 -1.0000]]
# Episode 11: Observation = [[-4.5196 1.0000]]
# Episode 11: Observation = [[0.1336 1.0000]]
# Episode 11: Observation = [[1.5170 1.0000]]
# Episode 11: Observation = [[-1.7842 1.0000]]
# Episode 11: Observation = [[-1.8510 1.0000]]
# Episode 11: Observation = [[-3.0516 1.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# Episode 11: Observation = [[0.0000 0.0000]]
# ...
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[-0.1771 1.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[-0.1771 1.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0886 -1.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 17: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[1.2809 -1.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[-0.0359 1.0000]]
# Episode 18: Observation = [[-0.5825 1.0000]]
# Episode 18: Observation = [[0.2329 1.0000]]
# Episode 18: Observation = [[0.1881 1.0000]]
# Episode 18: Observation = [[0.4214 1.0000]]
# Episode 18: Observation = [[0.7445 1.0000]]
# Episode 18: Observation = [[-0.1796 1.0000]]
# Episode 18: Observation = [[-0.4215 1.0000]]
# Episode 18: Observation = [[0.4575 1.0000]]
# Episode 18: Observation = [[-0.2243 1.0000]]
# Episode 18: Observation = [[-0.8333 1.0000]]
# Episode 18: Observation = [[-1.0103 1.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.2588 -1.0000]]
# Episode 18: Observation = [[-0.2586 1.0000]]
# Episode 18: Observation = [[-1.0861 1.0000]]
# Episode 18: Observation = [[0.3114 1.0000]]
# Episode 18: Observation = [[-0.6491 1.0000]]
# Episode 18: Observation = [[0.4711 1.0000]]
# Episode 18: Observation = [[0.5251 1.0000]]
# Episode 18: Observation = [[1.0788 1.0000]]
# Episode 18: Observation = [[-0.0268 1.0000]]
# Episode 18: Observation = [[-0.1696 1.0000]]
# Episode 18: Observation = [[0.0000 1.0000]]
# Episode 18: Observation = [[-0.0356 1.0000]]
# Episode 18: Observation = [[0.1965 1.0000]]
# Episode 18: Observation = [[1.0103 1.0000]]
# Episode 18: Observation = [[-0.1790 1.0000]]
# Episode 18: Observation = [[-0.4471 1.0000]]
# Episode 18: Observation = [[0.8930 -1.0000]]
# Episode 18: Observation = [[-0.0624 1.0000]]
# Episode 18: Observation = [[-0.4279 1.0000]]
# Episode 18: Observation = [[-1.4678 1.0000]]
# Episode 18: Observation = [[0.4620 1.0000]]
# Episode 18: Observation = [[-0.0356 1.0000]]
# Episode 18: Observation = [[0.3469 1.0000]]
# Episode 18: Observation = [[0.1334 1.0000]]
# Episode 18: Observation = [[0.8640 1.0000]]
# Episode 18: Observation = [[0.7140 1.0000]]
# Episode 18: Observation = [[-1.9784 1.0000]]
# Episode 18: Observation = [[-0.7904 1.0000]]
# Episode 18: Observation = [[-0.3105 1.0000]]
# Episode 18: Observation = [[-1.6992 1.0000]]
# Episode 18: Observation = [[-0.3619 1.0000]]
# Episode 18: Observation = [[-0.5386 -1.0000]]
# Episode 18: Observation = [[-0.2916 -1.0000]]
# Episode 18: Observation = [[-0.0442 -1.0000]]
# Episode 18: Observation = [[-0.1946 -1.0000]]
# Episode 18: Observation = [[0.7425 -1.0000]]
# Episode 18: Observation = [[0.0177 1.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.1850 -1.0000]]
# Episode 18: Observation = [[0.3348 1.0000]]
# Episode 18: Observation = [[-0.7921 1.0000]]
# Episode 18: Observation = [[0.1583 1.0000]]
# Episode 18: Observation = [[0.2639 1.0000]]
# Episode 18: Observation = [[0.4398 1.0000]]
# Episode 18: Observation = [[1.4283 1.0000]]
# Episode 18: Observation = [[-0.3796 1.0000]]
# Episode 18: Observation = [[0.7425 1.0000]]
# Episode 18: Observation = [[0.0088 1.0000]]
# Episode 18: Observation = [[-0.0883 1.0000]]
# Episode 18: Observation = [[0.4771 1.0000]]
# Episode 18: Observation = [[-1.6764 1.0000]]
# Episode 18: Observation = [[-0.9324 1.0000]]
# Episode 18: Observation = [[-0.9324 1.0000]]
# Episode 18: Observation = [[-0.1933 1.0000]]
# Episode 18: Observation = [[0.6067 1.0000]]
# Episode 18: Observation = [[-0.1230 1.0000]]
# Episode 18: Observation = [[0.4747 1.0000]]
# Episode 18: Observation = [[0.3867 1.0000]]
# Episode 18: Observation = [[-0.1056 1.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[-0.3599 -1.0000]]
# Episode 18: Observation = [[-0.6943 -1.0000]]
# Episode 18: Observation = [[-0.5273 -1.0000]]
# Episode 18: Observation = [[0.1671 -1.0000]]
# Episode 18: Observation = [[-0.4919 1.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.0000 0.0000]]
# Episode 18: Observation = [[0.6606 -1.0000]]
# Episode 18: Observation = [[-1.8091 1.0000]]
# Episode 18: Observation = [[-4.4300 1.0000]]
# Episode 18: Observation = [[-6.1941 1.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.1388 -1.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.4688 1.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 19: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[1.8712 -1.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[-0.3144 -1.0000]]
# Episode 20: Observation = [[-0.1415 -1.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[-1.3759 1.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.8884 -1.0000]]
# Episode 20: Observation = [[-5.0395 1.0000]]
# Episode 20: Observation = [[1.9734 1.0000]]
# Episode 20: Observation = [[-0.4874 1.0000]]
# Episode 20: Observation = [[-1.7296 1.0000]]
# Episode 20: Observation = [[-1.1714 1.0000]]
# Episode 20: Observation = [[-0.7470 1.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[-0.2909 -1.0000]]
# Episode 20: Observation = [[0.1494 -1.0000]]
# Episode 20: Observation = [[-0.5111 -1.0000]]
# Episode 20: Observation = [[-0.0236 -1.0000]]
# Episode 20: Observation = [[0.1336 -1.0000]]
# Episode 20: Observation = [[1.2028 -1.0000]]
# Episode 20: Observation = [[1.8239 -1.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.4167 1.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0000 0.0000]]
# Episode 20: Observation = [[0.0079 -1.0000]]
# Episode 20: Observation = [[-0.5032 -1.0000]]
# Episode 20: Observation = [[-0.5975 -1.0000]]
# Episode 20: Observation = [[-0.6604 -1.0000]]
# Episode 20: Observation = [[-0.8963 -1.0000]]
# Episode 20: Observation = [[-1.5960 -1.0000]]
# Episode 20: Observation = [[-0.5818 -1.0000]]
# Episode 20: Observation = [[-0.7705 -1.0000]]
# Episode 20: Observation = [[-0.8412 -1.0000]]
# Episode 20: Observation = [[-0.2594 1.0000]]
# -0.16776942

# %%
snapshot = tracemalloc.take_snapshot()
top_stats = snapshot.statistics('lineno')

for stat in top_stats[:10]:
    print(stat)
